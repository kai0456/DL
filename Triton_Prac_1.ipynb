# %% [markdown]
# <a href="https://colab.research.google.com/github/kai0456/DL/blob/master/Triton_Prac_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install triton
import torch
import triton
print(f"Triton version: {triton.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# ...
# Triton version: 3.5.0
# CUDA available: True

# %%
import torch
import triton
import triton.language as tl

@triton.jit
def add_kernel(
    x_ptr,  # Pointer to first input vector
    y_ptr,  # Pointer to second input vector
    output_ptr, # Pointer to output vector
    n_elements, # Total number of elements
    BLOCK_SIZE: tl.constexpr # Number of elements each program processes
):
    # 1. Identify which program instance this is
    pid = tl.program_id(axis=0)

    # 2. Calculate which data indices this program handles
    # ...
